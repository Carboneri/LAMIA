# %% [markdown]
# # Exercicio extra - Secao 6: Combinando KNN, PCA e Avaliacao de Classificadores
#
# Nas aulas desta secao voce aprendeu tres coisas separadamente: classificar dados com **KNN**, reduzir a dimensionalidade dos dados com **PCA**, e avaliar um classificador usando **matriz de confusao** e metricas como Precision, Recall e F1. Este exercicio pede para juntar os tres conceitos em um unico problema, usando o dataset **Wine** do scikit-learn (178 vinhos, 13 caracteristicas quimicas, 3 classes/tipos de vinho).

# %% [markdown]
# ## Activity
#
# 1. Carregue o dataset Wine (`sklearn.datasets.load_wine`) e separe em treino/teste.
# 2. Treine um classificador **KNN** para prever a classe (tipo) do vinho a partir das 13 caracteristicas.
# 3. Calcule a **matriz de confusao** do modelo no conjunto de teste e, a partir dela, calcule **Precision**, **Recall** e **F1 Score** para cada classe (dica: `sklearn.metrics` tem funcoes prontas, mas tente entender a formula por tras).
# 4. Teste pelo menos **3 valores diferentes de K** (por exemplo 1, 5 e 15) e monte uma tabela comparando a acuracia de cada um. Qual K teve o melhor resultado? Isso bate com o que foi discutido em aula sobre o efeito de K no bias/variancia?
# 5. Use **PCA** para reduzir as 13 caracteristicas para **2 componentes** e faca um grafico de dispersao colorido pelas classes reais. Nesse mesmo grafico (ou em um segundo, ao lado), destaque com um marcador diferente os pontos que o KNN **classificou errado** - eles aparecem perto das bordas entre os grupos, como seria esperado?
#
# ## Your Challenge
#
# Depois de resolver a Activity acima, va um pouco alem:
#
# - Normalize as features com `StandardScaler` antes de treinar o KNN (o dataset Wine tem colunas em escalas bem diferentes, como visto na aula sobre normalizacao) e compare a acuracia antes e depois de normalizar. O quanto isso muda o resultado?
# - Escolha uma das classes e calcule manualmente (sem usar `sklearn.metrics`) o Precision e o Recall dela a partir dos numeros da matriz de confusao, so para fixar a formula.
# - Bonus: o que aconteceria se voce treinasse o KNN diretamente nos 2 componentes do PCA, em vez das 13 features originais? A acuracia piora muito? Isso te diz algo sobre quanta informacao o PCA preservou?

# %% [markdown]
# ---
# ## Espaço para resolução

# %%
# 1. Carregando o dataset e separando treino/teste
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

wine = load_wine()
X = wine.data
y = wine.target

# TODO: separe X e y em treino e teste (dica: train_test_split, use random_state para reprodutibilidade)
X_train, X_test, y_train, y_test = None, None, None, None

# %%
# 2. Treinando o KNN
from sklearn.neighbors import KNeighborsClassifier

# TODO: crie e treine um KNeighborsClassifier (escolha um K inicial, por exemplo 5)
knn = None

# %%
# 3. Matriz de confusao e metricas
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score

# TODO: faca as previsoes no conjunto de teste e calcule a matriz de confusao
y_pred = None

# %%
# 4. Comparando diferentes valores de K
# TODO: monte um loop testando K = 1, 5, 15 (ou outros valores que quiser)
# e imprima a acuracia de cada um numa tabela simples

# %%
# 5. PCA para visualizacao 2D + destaque dos erros de classificacao
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# TODO: aplique PCA(n_components=2) nos dados, gere o scatter plot colorido pelas classes reais
# e marque com um simbolo diferente os pontos que o KNN classificou errado

# %% [markdown]
# ---
# ## Your Challenge - espaço para resolução

# %%
# Normalizando as features com StandardScaler e comparando a acuracia
from sklearn.preprocessing import StandardScaler

# TODO

# %%
# Calculando Precision e Recall manualmente para uma classe, a partir da matriz de confusao
# TODO

# %%
# Treinando o KNN diretamente nos 2 componentes do PCA e comparando a acuracia
# TODO
