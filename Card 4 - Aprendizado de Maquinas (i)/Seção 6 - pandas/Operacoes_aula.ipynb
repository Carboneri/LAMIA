# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique() #mantem apenas unicos valores
# Out:
# array([444, 555, 666])

# %%
np.unique(df['col2']) #mesma coisa mas com o np
# Out:
# array([444, 555, 666])

# %%
len(np.unique(df['col2'])) #tamanho do vetor de resposta
# Out:
# 3

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts() #une tanto o nunique quanto o unique
# Out:
# col2
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
df[(df['col1']>2)] #subconjunto de df
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df[(df['col1']>2) & (df['col2'] == 444)] #mais um subconjunto que passa oq vc quer q ele retorne
# Out:
#    col1  col2 col3
# 3     4   444  xyz

# %%
df.sum()
# Out:
# col1              10
# col2            2109
# col3    abcdefghixyz
# dtype: object

# %%
def vezes2(x): # faz * 2
    return x*2

# %%
df['col1'].sum()
# Out:
# np.int64(10)

# %%
df['col1'].apply(vezes2) #passa como parametro alguma funcao q criamos para fazer alguma coisa
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col3'].apply(len) #tamanho da coluna 3
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: col3, dtype: int64

# %%
df['col1'].apply(lambda x : x*x) #serve mais para n poluir o codigo, passando parametros lambda dentro de apply
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col1, dtype: int64

# %%
del df['col2'] #deleta coluna

# %%
df
# Out:
#    col1 col3
# 0     1  abc
# 1     2  def
# 2     3  ghi
# 3     4  xyz

# %%
df.columns
# Out:
# Index(['col1', 'col3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sort_values(by='col2', inplace = True)

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi>

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi>

# %%
df = pd.DataFrame({'col1':[1,2,3,np.nan],
                   'col2':[np.nan,555,666,444],
                   'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1   col2 col3
# 0   1.0    NaN  abc
# 1   2.0  555.0  def
# 2   3.0  666.0  ghi
# 3   NaN  444.0  xyz
