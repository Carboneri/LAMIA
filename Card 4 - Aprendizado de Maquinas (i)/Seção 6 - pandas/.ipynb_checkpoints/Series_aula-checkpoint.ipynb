# %%
import pandas as pd
import numpy as np

# %%
labels = ['a','b','c'] #cria uma lista

# %%
minha_lista = [10,20,30] #cria 3 lista mas cada uma de um jeito, uma que vai ser os indices da label, outra com o metodo do numpy e a outra da referenciando os indeces com os conteudo
arr = np.array([10,20,30])
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(data=minha_lista, index=labels)  #criando uma lista com indices utilizando o pandas
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
series = pd.Series(data=minha_lista, index=labels)

# %%
series['b'] #printando o conteudo do indice b
# Out:
# np.int64(20)

# %%
pd.Series(minha_lista,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,labels)#printando o array criado pelo numpy, da o mesmo resultado
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series([sum, print, len]) #uma lista de refenrenciacao dos metodos padroes do python com o pandas
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4], index=['EUA', 'alemanha', 'urss', 'japao']) #criando uma lista com indices

# %%
ser1
# Out:
# EUA         1
# alemanha    2
# urss        3
# japao       4
# dtype: int64

# %%
ser2 = pd.Series([1,2,3,4], index=['EUA', 'alemanha', 'italia', 'japao']) #criando uma lista com indices

# %%
ser2
# Out:
# EUA         1
# alemanha    2
# italia      3
# japao       4
# dtype: int64

# %%
ser1 + ser2 #soma baseada nos indices, porem italia e urss n tem relacao e retona nan
# Out:
# EUA         2.0
# alemanha    4.0
# italia      NaN
# japao       8.0
# urss        NaN
# dtype: float64
