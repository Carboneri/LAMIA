# %%
print("hello world")
# Out:
# hello world

# %%
1 + 1
# Out:
# 2

# %%
a = 1
print(a)
# Out:
# 1

# %%
print("hello")
# Out:
# hello

# %%
print (a)

# %% [markdown]
# a linha a baixo printara um texto qualquer

# %%
print("sla")
# Out:
# sla
